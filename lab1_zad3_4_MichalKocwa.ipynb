# %%
#Michał Kocwa

##Zadanie 3

import numpy as np
import matplotlib.pyplot as plt


def fun1(x):
  return x*x + 5


x = np.arange(-1,1,0.01)

plt.plot(x,fun1(x), label = "x^2+5")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.title('wykres 3.1')
plt.legend()
plt.show()

# %%
x = np.arange(-6,6,0.01)
plt.plot(x,fun1(x), label = "x^2+5")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.title('wykres 3.2')
plt.legend()
plt.show()

# %%
x = np.arange(0,5,0.01)
plt.plot(x,fun1(x), label = "x^2+5")
plt.ylabel('f(x)')
plt.xlabel('x')
plt.title('wykres 3.3')
plt.legend()
plt.show()

# %%
##Zadanie 4

import pandas as pd

d = {'name': ["Antoni", "Andrzej", "Adam", "Amadeusz", "Albert"],
     'surname': ["Abakanowicz", "Abramczyk ", "Adamiec", "Adamiuk ", "Adamkiewicz"],
     'age': [36, 34,31, 43, 34],
     'sex': ["male", "male", "male", "male", "male", ]}

df = pd.DataFrame(data=d)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
df.describe()
# Out:
#              age
# count   5.000000
# mean   35.600000
# std     4.505552
# min    31.000000
# 25%    34.000000
# 50%    34.000000
# 75%    36.000000
# max    43.000000

# %%
df.head(3)
# Out:
#       name      surname  age   sex
# 0   Antoni  Abakanowicz   36  male
# 1  Andrzej   Abramczyk    34  male
# 2     Adam      Adamiec   31  male
